# %% [markdown]
# # Video Game Sales Task

# %% [markdown]
# #### 1. Import pandas module as pd

# %%
import pandas as pd

# %%
#Добавил для визуализации
#для заданий требующих простого ответа графики убрал
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2. Create variable vgs and read vgsales.csv file as dataframe in it

# %%
 vgs = pd.read_csv('vgsales.csv')

# %% [markdown]
# #### 3. Get first 10 rows from the dataframe

# %%
vgs.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
top_10_games = vgs.head(10)
sales_columns = ['Name', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
sales_data = top_10_games[sales_columns]
sales_data.set_index('Name', inplace=True)
sales_data.plot(kind='bar', figsize=(12, 6), colormap='tab20')
plt.title('Sales Data of Top 10 Video Games')
plt.ylabel('Sales (in millions)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(title='Sales Regions')
plt.show()

# %% [markdown]
# #### 4. Use info() method to know the information about number of entries in vgs dataframe

# %%
vgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data_info = vgs.info() 
non_null_counts = vgs.notnull().sum()
data_types = vgs.dtypes
info_df = pd.DataFrame({
    'Non-Null Count': non_null_counts,
    'Data Type': data_types
}).reset_index()
plt.figure(figsize=(12, 6))
plt.bar(info_df['index'], info_df['Non-Null Count'], color='lightblue')
plt.title('Non-Null Counts of Each Column in Video Game Sales Data')
plt.ylabel('Non-Null Count')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# #### 5. Get average value of sales in Europe

# %%
vgs['EU_Sales'].mean()
# Out:
# 0.14665200626581515

# %%
#average_eu_sales = vgs['EU_Sales'].mean()
#average_sales_df = pd.DataFrame({'Average_EU_Sales': [average_eu_sales]})
#average_sales_df.reset_index(inplace=True)
#average_sales_df.columns = ['Metric', 'Value']  
#plt.figure(figsize=(8, 5))
#plt.bar(average_sales_df['Metric'], average_sales_df['Value'], color='skyblue')
#plt.title('Average Sales in Europe')
#plt.ylabel('Sales (in millions)')
#plt.xticks(rotation=45)
#plt.grid(axis='y')
#plt.show()

# %% [markdown]
# #### 6. Get the highest value of sales in Japan

# %%
vgs['JP_Sales'].max()
# Out:
# 10.22

# %%
#highest_jp_sales = vgs['JP_Sales'].max()
#highest_jp_sales_game = vgs.loc[vgs['JP_Sales'] == highest_jp_sales, 'Name'].values[0]
#sales_data = pd.DataFrame({'Game': [highest_jp_sales_game], 'JP_Sales': [highest_jp_sales]})
#sales_data.reset_index(drop=True, inplace=True)
#plt.figure(figsize=(8, 5))
#plt.bar(sales_data['Game'], sales_data['JP_Sales'], color='lightcoral')
#plt.title('Highest Sales in Japan')
#plt.ylabel('Sales (in millions)')
#plt.xticks(rotation=45)
#plt.grid(axis='y')
#plt.show()

# %% [markdown]
# #### 7. What is the genre of "Brain Age 2: More Training in Minutes a Day" video game?

# %%
vgs.loc[vgs['Name'] == 'Brain Age 2: More Training in Minutes a Day', 'Genre']
# Out:
# 27    Puzzle
# Name: Genre, dtype: object

# %%
#genre = vgs.loc[vgs['Name'] == 'Brain Age 2: More Training in Minutes a Day', 'Genre'].values[0]
#genre_df = pd.DataFrame({'Game': ['Brain Age 2: More Training in Minutes a Day'], 'Genre': [genre]})
#genre_df.reset_index(drop=True, inplace=True)
#plt.figure(figsize=(8, 5))
#plt.bar(genre_df['Game'], genre_df['Genre'].apply(lambda x: 1), color='lightgreen')  
#plt.title('Genre of "Brain Age 2: More Training in Minutes a Day"')
#plt.ylabel('Genre')
#plt.xticks(rotation=45)
#plt.yticks([])  
#plt.show()

# %% [markdown]
# #### 8. What is the amount of sales "Grand Theft Auto: Vice City" video game around the world?

# %%
vgs.loc[vgs['Name'] == 'Grand Theft Auto: Vice City', 'Global_Sales']
# Out:
# 24       16.15
# 13732     0.04
# Name: Global_Sales, dtype: float64

# %%
#global_sales = vgs.loc[vgs['Name'] == 'Grand Theft Auto: Vice City', 'Global_Sales'].values[0]
#sales_data = pd.DataFrame({'Game': ['Grand Theft Auto: Vice City'], 'Global_Sales': [global_sales]})
#sales_data.reset_index(drop=True, inplace=True)
#plt.figure(figsize=(8, 5))
#plt.bar(sales_data['Game'], sales_data['Global_Sales'], color='lightblue')
#plt.title('Global Sales of "Grand Theft Auto: Vice City"')
#plt.ylabel('Sales (in millions)')
#plt.xticks(rotation=45)
#plt.grid(axis='y')
#plt.show()

# %% [markdown]
# #### 9. Get the name of the video game which has the highest sales in North America

# %%
vgs.loc[vgs['NA_Sales'].idxmax(), 'Name']
# Out:
# 'Wii Sports'

# %%
#highest_na_sales_game = vgs.loc[vgs['NA_Sales'].idxmax(), 'Name']
#highest_na_sales_value = vgs['NA_Sales'].max()
#sales_data = pd.DataFrame({'Game': [highest_na_sales_game], 'NA_Sales': [highest_na_sales_value]})
#sales_data.reset_index(drop=True, inplace=True)
#plt.figure(figsize=(8, 5))
#plt.bar(sales_data['Game'], sales_data['NA_Sales'], color='orange')
#plt.title('Highest Sales in North America')
#plt.ylabel('Sales (in millions)')
#plt.xticks(rotation=45)
#plt.grid(axis='y')
#plt.show()

# %% [markdown]
# #### 10. Get the name of video game which has the smallest sales around the world

# %%
vgs.loc[vgs['Global_Sales'].idxmin(), 'Name']
# Out:
# 'Turok'

# %%
#smallest_global_sales_game = vgs.loc[vgs['Global_Sales'].idxmin(), 'Name']
#smallest_global_sales_value = vgs['Global_Sales'].min()
#sales_data = pd.DataFrame({'Game': [smallest_global_sales_game], 'Global_Sales': [smallest_global_sales_value]})
#sales_data.reset_index(drop=True, inplace=True)
#plt.figure(figsize=(8, 5))
#plt.bar(sales_data['Game'], sales_data['Global_Sales'], color='lightgreen')
#plt.title('Smallest Global Sales of Video Game')
#plt.ylabel('Sales (in millions)')
#plt.xticks(rotation=45)
#plt.grid(axis='y')
#plt.show()

# %%
# Out:
# 15980                                                Turok
# 15981                       Coven and Labyrinth of Refrain
# 15982    Super Battle For Money Sentouchuu: Kyuukyoku n...
# 15983                                     Dragon Zakura DS
# 15984                               Chameleon: To Dye For!
#                                ...
# 16593                   Woody Woodpecker in Crazy Castle 5
# 16594                        Men in Black II: Alien Escape
# 16595     SCORE International Baja 1000: The Official Game
# 16596                                           Know How 2
# 16597                                     Spirits & Spells
# Name: Name, Length: 618, dtype: object

# %% [markdown]
# #### 11. What is the average value of sales of all video games per genre in Japan?

# %%
average_sales_per_genre = vgs.groupby('Genre')['JP_Sales'].mean().reset_index()
average_sales_per_genre.columns = ['Genre', 'Average_JP_Sales']
average_sales_per_genre
# Out:
#            Genre  Average_JP_Sales
# 0         Action          0.048236
# 1      Adventure          0.040490
# 2       Fighting          0.103007
# 3           Misc          0.061967
# 4       Platform          0.147596
# 5         Puzzle          0.098471
# 6         Racing          0.045388
# 7   Role-Playing          0.236767
# 8        Shooter          0.029221
# 9     Simulation          0.073472
# 10        Sports          0.057702
# 11      Strategy          0.072628

# %%
average_sales_per_genre = vgs.groupby('Genre')['JP_Sales'].mean().reset_index()
average_sales_per_genre.columns = ['Genre', 'Average_JP_Sales'] 
plt.figure(figsize=(12, 6))
plt.bar(average_sales_per_genre['Genre'], average_sales_per_genre['Average_JP_Sales'], color='lightblue')
plt.title('Average Sales of Video Games per Genre in Japan')
plt.ylabel('Average Sales (in millions)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Out:
# Genre
# Action          0.048236
# Adventure       0.040490
# Fighting        0.103007
# Misc            0.061967
# Platform        0.147596
# Puzzle          0.098471
# Racing          0.045388
# Role-Playing    0.236767
# Shooter         0.029221
# Simulation      0.073472
# Sports          0.057702
# Strategy        0.072628
# Name: JP_Sales, dtype: float64

# %% [markdown]
# #### 12. How many unique names of video games in this dataframe?

# %%
 vgs['Name'].nunique()
# Out:
# 11493

# %%
#unique_game_names_count = vgs['Name'].nunique()
#unique_games_data = pd.DataFrame({'Metric': ['Unique Video Game Names'], 'Count': [unique_game_names_count]})
#unique_games_data.reset_index(drop=True, inplace=True)
#plt.figure(figsize=(8, 5))
#plt.bar(unique_games_data['Metric'], unique_games_data['Count'], color='purple')
#plt.title('Number of Unique Video Game Names')
#plt.ylabel('Count')
#plt.xticks(rotation=45)
#plt.grid(axis='y')
#plt.show()

# %% [markdown]
# #### 13. Get the 3 most common genres of video games worldwide

# %%
vgs['Genre'].value_counts().head(3).reset_index()
# Out:
#     Genre  count
# 0  Action   3316
# 1  Sports   2346
# 2    Misc   1739

# %%
common_genres = vgs['Genre'].value_counts().head(3).reset_index()
common_genres.columns = ['Genre', 'Count']
plt.figure(figsize=(10, 6))
plt.bar(common_genres['Genre'], common_genres['Count'], color='skyblue')
plt.title('Three Most Common Genres of Video Games Worldwide')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### 14. How many video games have "super" word in their names?

# %%
vgs[vgs['Name'].str.contains('super', case=False, na=False)]['Name'].drop_duplicates().count()
#содержит ли имя слово "super", игнорируя верхний и нижний регистр без дубликатов если в названии игр несколько super
# Out:
# 283

# %%
#super_games_count = vgs[vgs['Name'].str.contains('super', case=False, na=False)]['Name'].drop_duplicates().count()
#super_games_data = pd.DataFrame({'Metric': ['Unique Video Games with "Super"'], 'Count': [super_games_count]})
#super_games_data.reset_index(drop=True, inplace=True)
#plt.figure(figsize=(8, 5))
#plt.bar(super_games_data['Metric'], super_games_data['Count'], color='orange')
#plt.title('Number of Unique Video Games Containing "Super"')
#plt.ylabel('Count')
#plt.xticks(rotation=45)
#plt.grid(axis='y')
#plt.show()
